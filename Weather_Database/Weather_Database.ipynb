# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 784

# %%
weather_api_key = ""

# %%
# Import the requests & sys libraries.
import requests
import config
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description =  city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ionia
# Processing Record 2 of Set 1 | samarai
# Processing Record 3 of Set 1 | cusuna
# Processing Record 4 of Set 1 | krasnoarmeysk
# Processing Record 5 of Set 1 | pevek
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | makakilo city
# Processing Record 9 of Set 1 | bilma
# Processing Record 10 of Set 1 | barkly west
# Processing Record 11 of Set 1 | tommot
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | araouane
# Processing Record 15 of Set 1 | teguise
# Processing Record 16 of Set 1 | olafsvik
# Processing Record 17 of Set 1 | kiama
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | gamba
# Processing Record 21 of Set 1 | hofn
# Processing Record 22 of Set 1 | puerto escondido
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | frata
# Processing Record 25 of Set 1 | saint-denis
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | sao joao da barra
# Processing Record 28 of Set 1 | cumbitara
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | deputatskiy
# Processing Record 34 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 1 | saint george
# Processing Record 36 of Set 1 | tapejara
# Processing Record 37 of Set 1 | pisco
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | dingle
# Processing Record 40 of Set 1 | provideniya
# Processing Record 41 of Set 1 | udachnyy
# Processing Record 42 of Set 1 | luba
# Processing Record 43 of Set 1 | roma
# Processing Record 44 of Set 1 | igrim
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | talnakh
# Processing Record 48 of Set 1 | edeia
# Processing Record 49 of Set 1 | lagoa
# Processing Record 50 of Set 1 | pangnirtung
# Processing Record 1 of Set 2 | cayenne
# Processing Record 2 of Set 2 | port augusta
# Processing Record 3 of Set 2 | cidreira
# Processing Record 4 of Set 2 | sheltozero
# Processing Record 5 of Set 2 | aripuana
# Processing Record 6 of Set 2 | areosa
# Processing Record 7 of Set 2 | tuatapere
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | grand gaube
# Processing Record 12 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 2 | esperance
# Processing Record 14 of Set 2 | severodvinsk
# Processing Record 15 of Set 2 | bengkulu
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | saint anthony
# Processing Record 18 of Set 2 | khandagayty
# Processing Record 19 of Set 2 | portland
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | ancud
# Processing Record 22 of Set 2 | broken hill
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | iqaluit
# Processing Record 25 of Set 2 | faanui
# Processing Record 26 of Set 2 | kyotera
# Processing Record 27 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 2 | santa fe
# Processing Record 29 of Set 2 | novita
# Processing Record 30 of Set 2 | new norfolk
# Processing Record 31 of Set 2 | punta arenas
# Processing Record 32 of Set 2 | airai
# Processing Record 33 of Set 2 | lompoc
# Processing Record 34 of Set 2 | mar del plata
# Processing Record 35 of Set 2 | dongning
# Processing Record 36 of Set 2 | souillac
# Processing Record 37 of Set 2 | hermanus
# Processing Record 38 of Set 2 | buala
# Processing Record 39 of Set 2 | paragominas
# Processing Record 40 of Set 2 | bighapur
# Processing Record 41 of Set 2 | puerto ayacucho
# Processing Record 42 of Set 2 | torbay
# Processing Record 43 of Set 2 | kugulta
# Processing Record 44 of Set 2 | saskylakh
# Processing Record 45 of Set 2 | dovolnoye
# Processing Record 46 of Set 2 | butterworth
# Processing Record 47 of Set 2 | dicabisagan
# Processing Record 48 of Set 2 | kibaek
# Processing Record 49 of Set 2 | paamiut
# Processing Record 50 of Set 2 | tuktoyaktuk
# Processing Record 1 of Set 3 | ahipara
# Processing Record 2 of Set 3 | gushikawa
# Processing Record 3 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 3 | georgetown
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | sinnamary
# Processing Record 7 of Set 3 | tigil
# Processing Record 8 of Set 3 | sur
# Processing Record 9 of Set 3 | den helder
# Processing Record 10 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | hasaki
# Processing Record 13 of Set 3 | jamestown
# Processing Record 14 of Set 3 | odweyne
# Processing Record 15 of Set 3 | cabo san lucas
# Processing Record 16 of Set 3 | palm coast
# Processing Record 17 of Set 3 | port keats
# Processing Record 18 of Set 3 | thompson
# Processing Record 19 of Set 3 | east london
# Processing Record 20 of Set 3 | pulandian
# Processing Record 21 of Set 3 | altamira
# Processing Record 22 of Set 3 | bardiyah
# Processing Record 23 of Set 3 | katsuura
# Processing Record 24 of Set 3 | severo-kurilsk
# Processing Record 25 of Set 3 | tome
# Processing Record 26 of Set 3 | geraldton
# Processing Record 27 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 3 | thanh hoa
# Processing Record 29 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 3 | north battleford
# Processing Record 31 of Set 3 | tucuma
# Processing Record 32 of Set 3 | ilhabela
# Processing Record 33 of Set 3 | kotagiri
# Processing Record 34 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 3 | resistencia
# Processing Record 36 of Set 3 | cabra
# Processing Record 37 of Set 3 | jining
# Processing Record 38 of Set 3 | saint-augustin
# Processing Record 39 of Set 3 | cherskiy
# Processing Record 40 of Set 3 | hobart
# Processing Record 41 of Set 3 | mehamn
# Processing Record 42 of Set 3 | castro
# Processing Record 43 of Set 3 | vao
# Processing Record 44 of Set 3 | khatanga
# Processing Record 45 of Set 3 | krasnoselkup
# Processing Record 46 of Set 3 | namikupa
# Processing Record 47 of Set 3 | kulhudhuffushi
# Processing Record 48 of Set 3 | levelland
# Processing Record 49 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 3 | kanniyakumari
# Processing Record 1 of Set 4 | nishihara
# Processing Record 2 of Set 4 | mount gambier
# Processing Record 3 of Set 4 | lima
# Processing Record 4 of Set 4 | richards bay
# Processing Record 5 of Set 4 | esik
# Processing Record 6 of Set 4 | lazaro cardenas
# Processing Record 7 of Set 4 | fukue
# Processing Record 8 of Set 4 | svetlaya
# Processing Record 9 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 10 of Set 4 | bluff
# Processing Record 11 of Set 4 | araxa
# Processing Record 12 of Set 4 | sitka
# Processing Record 13 of Set 4 | zheleznodorozhnyy
# Processing Record 14 of Set 4 | lebu
# Processing Record 15 of Set 4 | oranjestad
# Processing Record 16 of Set 4 | aklavik
# Processing Record 17 of Set 4 | goderich
# Processing Record 18 of Set 4 | san patricio
# Processing Record 19 of Set 4 | carnarvon
# Processing Record 20 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 4 | komsomolskiy
# Processing Record 22 of Set 4 | ugoofaaru
# Processing Record 23 of Set 4 | upernavik
# Processing Record 24 of Set 4 | parfino
# Processing Record 25 of Set 4 | morondava
# Processing Record 26 of Set 4 | barrow
# Processing Record 27 of Set 4 | vila franca do campo
# Processing Record 28 of Set 4 | porosozero
# Processing Record 29 of Set 4 | camana
# Processing Record 30 of Set 4 | kavaratti
# Processing Record 31 of Set 4 | codrington
# Processing Record 32 of Set 4 | conceicao do araguaia
# Processing Record 33 of Set 4 | santa luzia
# Processing Record 34 of Set 4 | hithadhoo
# Processing Record 35 of Set 4 | la spezia
# Processing Record 36 of Set 4 | yoichi
# Processing Record 37 of Set 4 | khammam
# Processing Record 38 of Set 4 | jackson
# Processing Record 39 of Set 4 | bahar
# Processing Record 40 of Set 4 | lyngseidet
# Processing Record 41 of Set 4 | guerrero negro
# Processing Record 42 of Set 4 | avarua
# Processing Record 43 of Set 4 | rognan
# Processing Record 44 of Set 4 | chokurdakh
# Processing Record 45 of Set 4 | biu
# Processing Record 46 of Set 4 | nome
# Processing Record 47 of Set 4 | kijang
# Processing Record 48 of Set 4 | butaritari
# Processing Record 49 of Set 4 | dikson
# Processing Record 50 of Set 4 | huarmey
# Processing Record 1 of Set 5 | kodiak
# Processing Record 2 of Set 5 | ardesen
# Processing Record 3 of Set 5 | mansehra
# Processing Record 4 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 5 | tautira
# Processing Record 6 of Set 5 | broome
# Processing Record 7 of Set 5 | bhunya
# Processing Record 8 of Set 5 | namibe
# Processing Record 9 of Set 5 | fairbanks
# Processing Record 10 of Set 5 | sao miguel do araguaia
# Processing Record 11 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 12 of Set 5 | bonthe
# Processing Record 13 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 14 of Set 5 | viedma
# Processing Record 15 of Set 5 | puli
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | hammerfest
# Processing Record 18 of Set 5 | tasiilaq
# Processing Record 19 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 5 | kalat
# Processing Record 21 of Set 5 | faya
# Processing Record 22 of Set 5 | vanderhoof
# Processing Record 23 of Set 5 | mahebourg
# Processing Record 24 of Set 5 | bastrop
# Processing Record 25 of Set 5 | saint-philippe
# Processing Record 26 of Set 5 | taseyevo
# Processing Record 27 of Set 5 | sao filipe
# Processing Record 28 of Set 5 | atbasar
# Processing Record 29 of Set 5 | ponta do sol
# Processing Record 30 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 31 of Set 5 | sturgis
# Processing Record 32 of Set 5 | bonavista
# Processing Record 33 of Set 5 | coihaique
# Processing Record 34 of Set 5 | chantada
# Processing Record 35 of Set 5 | chuy
# Processing Record 36 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 5 | bossangoa
# Processing Record 38 of Set 5 | singleton
# Processing Record 39 of Set 5 | kimbe
# Processing Record 40 of Set 5 | namatanai
# Processing Record 41 of Set 5 | dunayivtsi
# City not found. Skipping...
# Processing Record 42 of Set 5 | salamiyah
# Processing Record 43 of Set 5 | mujiayingzi
# Processing Record 44 of Set 5 | narsaq
# Processing Record 45 of Set 5 | yulara
# Processing Record 46 of Set 5 | pundaguitan
# Processing Record 47 of Set 5 | sulangan
# Processing Record 48 of Set 5 | porto santo
# Processing Record 49 of Set 5 | valdivia
# Processing Record 50 of Set 5 | havre-saint-pierre
# Processing Record 1 of Set 6 | talara
# Processing Record 2 of Set 6 | caravelas
# Processing Record 3 of Set 6 | majene
# Processing Record 4 of Set 6 | sao raimundo das mangabeiras
# Processing Record 5 of Set 6 | kavieng
# Processing Record 6 of Set 6 | sorland
# Processing Record 7 of Set 6 | la mira
# Processing Record 8 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 6 | alice springs
# Processing Record 10 of Set 6 | flinders
# Processing Record 11 of Set 6 | iquique
# Processing Record 12 of Set 6 | vanavara
# Processing Record 13 of Set 6 | buenos aires
# Processing Record 14 of Set 6 | port lincoln
# Processing Record 15 of Set 6 | ambon
# Processing Record 16 of Set 6 | bambous virieux
# Processing Record 17 of Set 6 | lumphat
# Processing Record 18 of Set 6 | half moon bay
# Processing Record 19 of Set 6 | goba
# Processing Record 20 of Set 6 | karratha
# Processing Record 21 of Set 6 | manyana
# Processing Record 22 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 23 of Set 6 | inhambane
# Processing Record 24 of Set 6 | umm kaddadah
# Processing Record 25 of Set 6 | joshimath
# Processing Record 26 of Set 6 | norman wells
# Processing Record 27 of Set 6 | the valley
# Processing Record 28 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 29 of Set 6 | ishigaki
# Processing Record 30 of Set 6 | darhan
# Processing Record 31 of Set 6 | north bend
# Processing Record 32 of Set 6 | moskovskiy
# Processing Record 33 of Set 6 | muravlenko
# Processing Record 34 of Set 6 | fort nelson
# Processing Record 35 of Set 6 | maniitsoq
# Processing Record 36 of Set 6 | arman
# Processing Record 37 of Set 6 | maracas
# Processing Record 38 of Set 6 | bangassou
# Processing Record 39 of Set 6 | nambiyur
# Processing Record 40 of Set 6 | creel
# Processing Record 41 of Set 6 | sheksna
# Processing Record 42 of Set 6 | ucluelet
# Processing Record 43 of Set 6 | merauke
# Processing Record 44 of Set 6 | gualaceo
# Processing Record 45 of Set 6 | andradas
# Processing Record 46 of Set 6 | dehloran
# Processing Record 47 of Set 6 | bonfim
# Processing Record 48 of Set 6 | saldanha
# Processing Record 49 of Set 6 | olinda
# Processing Record 50 of Set 6 | tocopilla
# Processing Record 1 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 7 | baker city
# Processing Record 3 of Set 7 | marquette
# Processing Record 4 of Set 7 | amazar
# Processing Record 5 of Set 7 | waiuku
# Processing Record 6 of Set 7 | gold coast
# Processing Record 7 of Set 7 | mahon
# Processing Record 8 of Set 7 | leamington
# Processing Record 9 of Set 7 | bayan
# Processing Record 10 of Set 7 | kurchatov
# Processing Record 11 of Set 7 | taganak
# Processing Record 12 of Set 7 | kasamatsu
# Processing Record 13 of Set 7 | tevriz
# Processing Record 14 of Set 7 | belyy yar
# Processing Record 15 of Set 7 | fort william
# Processing Record 16 of Set 7 | misratah
# Processing Record 17 of Set 7 | lavrentiya
# Processing Record 18 of Set 7 | oruro
# Processing Record 19 of Set 7 | luena
# Processing Record 20 of Set 7 | laguna
# Processing Record 21 of Set 7 | macae
# Processing Record 22 of Set 7 | miri
# Processing Record 23 of Set 7 | quatre cocos
# Processing Record 24 of Set 7 | griffith
# Processing Record 25 of Set 7 | severnoye
# Processing Record 26 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 7 | aswan
# Processing Record 28 of Set 7 | monte santo de minas
# Processing Record 29 of Set 7 | marsaxlokk
# Processing Record 30 of Set 7 | mount isa
# Processing Record 31 of Set 7 | zhezkazgan
# Processing Record 32 of Set 7 | nzega
# Processing Record 33 of Set 7 | riyadh
# Processing Record 34 of Set 7 | maningrida
# Processing Record 35 of Set 7 | jijiga
# Processing Record 36 of Set 7 | grindavik
# Processing Record 37 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 7 | cochrane
# Processing Record 39 of Set 7 | tarauaca
# Processing Record 40 of Set 7 | nabire
# Processing Record 41 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 7 | meulaboh
# Processing Record 44 of Set 7 | coahuayana
# Processing Record 45 of Set 7 | iganga
# Processing Record 46 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 7 | muros
# Processing Record 48 of Set 7 | college
# Processing Record 49 of Set 7 | maumere
# Processing Record 50 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 8 | verkhoyansk
# Processing Record 2 of Set 8 | hobyo
# Processing Record 3 of Set 8 | mumbwa
# Processing Record 4 of Set 8 | husavik
# Processing Record 5 of Set 8 | scarborough
# Processing Record 6 of Set 8 | dalbandin
# Processing Record 7 of Set 8 | peniche
# Processing Record 8 of Set 8 | massaguet
# Processing Record 9 of Set 8 | eyl
# Processing Record 10 of Set 8 | camacha
# Processing Record 11 of Set 8 | barra
# Processing Record 12 of Set 8 | valparaiso
# Processing Record 13 of Set 8 | bethel
# Processing Record 14 of Set 8 | port-gentil
# Processing Record 15 of Set 8 | polunochnoye
# Processing Record 16 of Set 8 | marawi
# Processing Record 17 of Set 8 | musoma
# Processing Record 18 of Set 8 | riohacha
# Processing Record 19 of Set 8 | arak
# Processing Record 20 of Set 8 | queimados
# Processing Record 21 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 8 | tomatlan
# Processing Record 23 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 8 | gidole
# Processing Record 25 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 26 of Set 8 | san quintin
# Processing Record 27 of Set 8 | lebanon
# Processing Record 28 of Set 8 | putyatino
# Processing Record 29 of Set 8 | mahendranagar
# Processing Record 30 of Set 8 | tamandare
# Processing Record 31 of Set 8 | chapais
# Processing Record 32 of Set 8 | ossora
# Processing Record 33 of Set 8 | dawei
# Processing Record 34 of Set 8 | cockburn town
# Processing Record 35 of Set 8 | vestmannaeyjar
# Processing Record 36 of Set 8 | piranshahr
# Processing Record 37 of Set 8 | maksi
# Processing Record 38 of Set 8 | clyde river
# Processing Record 39 of Set 8 | champerico
# Processing Record 40 of Set 8 | walvis bay
# Processing Record 41 of Set 8 | bud
# Processing Record 42 of Set 8 | tura
# Processing Record 43 of Set 8 | marzuq
# Processing Record 44 of Set 8 | madras
# Processing Record 45 of Set 8 | okha
# Processing Record 46 of Set 8 | los llanos de aridane
# Processing Record 47 of Set 8 | isangel
# Processing Record 48 of Set 8 | iskateley
# Processing Record 49 of Set 8 | san joaquin
# Processing Record 50 of Set 8 | port hardy
# Processing Record 1 of Set 9 | sabang
# Processing Record 2 of Set 9 | hongjiang
# Processing Record 3 of Set 9 | bubaque
# Processing Record 4 of Set 9 | ponta delgada
# Processing Record 5 of Set 9 | sembakung
# Processing Record 6 of Set 9 | kununurra
# Processing Record 7 of Set 9 | kenora
# Processing Record 8 of Set 9 | susanville
# Processing Record 9 of Set 9 | benguela
# Processing Record 10 of Set 9 | palaia fokaia
# Processing Record 11 of Set 9 | oranjemund
# Processing Record 12 of Set 9 | burica
# City not found. Skipping...
# Processing Record 13 of Set 9 | alofi
# Processing Record 14 of Set 9 | aysha
# Processing Record 15 of Set 9 | bathsheba
# Processing Record 16 of Set 9 | yumen
# Processing Record 17 of Set 9 | semporna
# Processing Record 18 of Set 9 | gizo
# Processing Record 19 of Set 9 | san matias
# Processing Record 20 of Set 9 | kailua
# Processing Record 21 of Set 9 | chimbarongo
# Processing Record 22 of Set 9 | yarmouth
# Processing Record 23 of Set 9 | havoysund
# Processing Record 24 of Set 9 | puerto cabezas
# Processing Record 25 of Set 9 | padang
# Processing Record 26 of Set 9 | teguldet
# Processing Record 27 of Set 9 | uyuni
# Processing Record 28 of Set 9 | manggar
# Processing Record 29 of Set 9 | tateyama
# Processing Record 30 of Set 9 | ereymentau
# Processing Record 31 of Set 9 | george town
# Processing Record 32 of Set 9 | palmer
# Processing Record 33 of Set 9 | ampanihy
# Processing Record 34 of Set 9 | malindi
# Processing Record 35 of Set 9 | chamalieres
# Processing Record 36 of Set 9 | nyurba
# Processing Record 37 of Set 9 | alice
# Processing Record 38 of Set 9 | san isidro
# Processing Record 39 of Set 9 | port macquarie
# Processing Record 40 of Set 9 | ranong
# Processing Record 41 of Set 9 | mandalgovi
# Processing Record 42 of Set 9 | shihezi
# Processing Record 43 of Set 9 | ahome
# Processing Record 44 of Set 9 | isla mujeres
# Processing Record 45 of Set 9 | andenes
# Processing Record 46 of Set 9 | carmen
# Processing Record 47 of Set 9 | kloulklubed
# Processing Record 48 of Set 9 | trofors
# Processing Record 49 of Set 9 | rawlins
# Processing Record 50 of Set 9 | seoul
# Processing Record 1 of Set 10 | itaituba
# Processing Record 2 of Set 10 | flagstaff
# Processing Record 3 of Set 10 | trenggalek
# Processing Record 4 of Set 10 | kruisfontein
# Processing Record 5 of Set 10 | victoria
# Processing Record 6 of Set 10 | saint-joseph
# Processing Record 7 of Set 10 | hervey bay
# Processing Record 8 of Set 10 | taylor
# Processing Record 9 of Set 10 | mayo
# Processing Record 10 of Set 10 | ostrovnoy
# Processing Record 11 of Set 10 | cooma
# Processing Record 12 of Set 10 | tiarei
# Processing Record 13 of Set 10 | doka
# Processing Record 14 of Set 10 | brae
# Processing Record 15 of Set 10 | gore
# Processing Record 16 of Set 10 | poienile de sub munte
# Processing Record 17 of Set 10 | caronport
# Processing Record 18 of Set 10 | yenagoa
# Processing Record 19 of Set 10 | irbit
# Processing Record 20 of Set 10 | ndele
# Processing Record 21 of Set 10 | kichera
# Processing Record 22 of Set 10 | belfast
# Processing Record 23 of Set 10 | larsnes
# Processing Record 24 of Set 10 | koutiala
# Processing Record 25 of Set 10 | hamilton
# Processing Record 26 of Set 10 | paracuru
# Processing Record 27 of Set 10 | kachug
# Processing Record 28 of Set 10 | mackay
# Processing Record 29 of Set 10 | praya
# Processing Record 30 of Set 10 | nanortalik
# Processing Record 31 of Set 10 | lasa
# Processing Record 32 of Set 10 | fortuna
# Processing Record 33 of Set 10 | san policarpo
# Processing Record 34 of Set 10 | isshiki
# City not found. Skipping...
# Processing Record 35 of Set 10 | rorvik
# Processing Record 36 of Set 10 | madinat sittah uktubar
# Processing Record 37 of Set 10 | kjollefjord
# Processing Record 38 of Set 10 | kaitangata
# Processing Record 39 of Set 10 | seymchan
# Processing Record 40 of Set 10 | turukhansk
# Processing Record 41 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 10 | kasongo-lunda
# Processing Record 43 of Set 10 | marietta
# Processing Record 44 of Set 10 | kem
# Processing Record 45 of Set 10 | terme
# Processing Record 46 of Set 10 | cape coast
# Processing Record 47 of Set 10 | nouadhibou
# Processing Record 48 of Set 10 | labuan
# Processing Record 49 of Set 10 | inuvik
# Processing Record 50 of Set 10 | nemuro
# Processing Record 1 of Set 11 | camaqua
# Processing Record 2 of Set 11 | hami
# Processing Record 3 of Set 11 | lephepe
# City not found. Skipping...
# Processing Record 4 of Set 11 | sulphur
# Processing Record 5 of Set 11 | bumba
# Processing Record 6 of Set 11 | tukan
# Processing Record 7 of Set 11 | barra do corda
# Processing Record 8 of Set 11 | lodja
# Processing Record 9 of Set 11 | belmonte
# Processing Record 10 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 11 of Set 11 | skibbereen
# Processing Record 12 of Set 11 | nieuw amsterdam
# Processing Record 13 of Set 11 | linshu
# City not found. Skipping...
# Processing Record 14 of Set 11 | clovis
# Processing Record 15 of Set 11 | tazovskiy
# Processing Record 16 of Set 11 | lata
# Processing Record 17 of Set 11 | vila
# Processing Record 18 of Set 11 | abu samrah
# Processing Record 19 of Set 11 | delta
# Processing Record 20 of Set 11 | kamenka
# Processing Record 21 of Set 11 | prince george
# Processing Record 22 of Set 11 | morant bay
# Processing Record 23 of Set 11 | longyearbyen
# Processing Record 24 of Set 11 | mecca
# Processing Record 25 of Set 11 | saint-pierre
# Processing Record 26 of Set 11 | sergiyevsk
# Processing Record 27 of Set 11 | giyani
# Processing Record 28 of Set 11 | saint-francois
# Processing Record 29 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 11 | axim
# Processing Record 31 of Set 11 | zabid
# Processing Record 32 of Set 11 | cap malheureux
# Processing Record 33 of Set 11 | minot
# Processing Record 34 of Set 11 | tammisaari
# Processing Record 35 of Set 11 | umm lajj
# Processing Record 36 of Set 11 | stokmarknes
# Processing Record 37 of Set 11 | bendigo
# Processing Record 38 of Set 11 | mildura
# Processing Record 39 of Set 11 | aykhal
# Processing Record 40 of Set 11 | balatan
# Processing Record 41 of Set 11 | ulaangom
# Processing Record 42 of Set 11 | atherton
# Processing Record 43 of Set 11 | babayurt
# Processing Record 44 of Set 11 | westport
# Processing Record 45 of Set 11 | onega
# Processing Record 46 of Set 11 | loandjili
# Processing Record 47 of Set 11 | mabaruma
# Processing Record 48 of Set 11 | ilulissat
# Processing Record 49 of Set 11 | vila velha
# Processing Record 50 of Set 11 | homer
# Processing Record 1 of Set 12 | xai-xai
# Processing Record 2 of Set 12 | marsh harbour
# Processing Record 3 of Set 12 | marienburg
# Processing Record 4 of Set 12 | beyneu
# Processing Record 5 of Set 12 | srednekolymsk
# Processing Record 6 of Set 12 | birao
# Processing Record 7 of Set 12 | villany
# Processing Record 8 of Set 12 | coruripe
# Processing Record 9 of Set 12 | pontes e lacerda
# Processing Record 10 of Set 12 | asau
# Processing Record 11 of Set 12 | sola
# Processing Record 12 of Set 12 | carauari
# Processing Record 13 of Set 12 | sabya
# Processing Record 14 of Set 12 | chengde
# Processing Record 15 of Set 12 | lukino
# Processing Record 16 of Set 12 | yar-sale
# Processing Record 17 of Set 12 | santa cruz
# Processing Record 18 of Set 12 | anadyr
# Processing Record 19 of Set 12 | maldonado
# Processing Record 20 of Set 12 | great bend
# Processing Record 21 of Set 12 | basti
# Processing Record 22 of Set 12 | kemijarvi
# Processing Record 23 of Set 12 | shakhtinsk
# Processing Record 24 of Set 12 | tessalit
# Processing Record 25 of Set 12 | wajima
# Processing Record 26 of Set 12 | kirakira
# Processing Record 27 of Set 12 | bintulu
# Processing Record 28 of Set 12 | glendive
# Processing Record 29 of Set 12 | kirando
# Processing Record 30 of Set 12 | sembe
# Processing Record 31 of Set 12 | alekseyevka
# Processing Record 32 of Set 12 | sovetsk
# Processing Record 33 of Set 12 | dhidhdhoo
# Processing Record 34 of Set 12 | hinton
# Processing Record 35 of Set 12 | kirkcudbright
# Processing Record 36 of Set 12 | ayagoz
# Processing Record 37 of Set 12 | wenzhou
# Processing Record 38 of Set 12 | hambantota
# Processing Record 39 of Set 12 | messina
# Processing Record 40 of Set 12 | presidencia roque saenz pena
# Processing Record 41 of Set 12 | swellendam
# Processing Record 42 of Set 12 | tombouctou
# Processing Record 43 of Set 12 | liverpool
# Processing Record 44 of Set 12 | akyab
# Processing Record 45 of Set 12 | soledad
# Processing Record 46 of Set 12 | nantucket
# Processing Record 47 of Set 12 | rio grande
# Processing Record 48 of Set 12 | waki
# Processing Record 49 of Set 12 | santiago
# Processing Record 50 of Set 12 | nisia floresta
# Processing Record 1 of Set 13 | adrar
# Processing Record 2 of Set 13 | campbell river
# Processing Record 3 of Set 13 | formosa
# Processing Record 4 of Set 13 | slave lake
# Processing Record 5 of Set 13 | benjamin aceval
# Processing Record 6 of Set 13 | cascais
# Processing Record 7 of Set 13 | sterling
# Processing Record 8 of Set 13 | anchorage
# Processing Record 9 of Set 13 | san cristobal
# Processing Record 10 of Set 13 | bolshoye selo
# Processing Record 11 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 13 | whitehorse
# Processing Record 13 of Set 13 | mopti
# Processing Record 14 of Set 13 | kalmunai
# Processing Record 15 of Set 13 | umarkot
# Processing Record 16 of Set 13 | egvekinot
# Processing Record 17 of Set 13 | yorosso
# Processing Record 18 of Set 13 | itoman
# Processing Record 19 of Set 13 | kahului
# Processing Record 20 of Set 13 | hvolsvollur
# Processing Record 21 of Set 13 | bandarbeyla
# Processing Record 22 of Set 13 | tahta
# Processing Record 23 of Set 13 | alexandria
# Processing Record 24 of Set 13 | belaya gora
# Processing Record 25 of Set 13 | nuevo progreso
# Processing Record 26 of Set 13 | solwezi
# Processing Record 27 of Set 13 | comodoro rivadavia
# Processing Record 28 of Set 13 | lakes entrance
# Processing Record 29 of Set 13 | raudeberg
# Processing Record 30 of Set 13 | antananarivo
# Processing Record 31 of Set 13 | zeya
# Processing Record 32 of Set 13 | harnosand
# Processing Record 33 of Set 13 | maryborough
# Processing Record 34 of Set 13 | jacqueville
# Processing Record 35 of Set 13 | carutapera
# Processing Record 36 of Set 13 | oxelosund
# Processing Record 37 of Set 13 | nador
# Processing Record 38 of Set 13 | xuddur
# Processing Record 39 of Set 13 | sayyan
# Processing Record 40 of Set 13 | klaksvik
# Processing Record 41 of Set 13 | ribeira brava
# Processing Record 42 of Set 13 | pahrump
# Processing Record 43 of Set 13 | minab
# Processing Record 44 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 13 | dongsheng
# Processing Record 46 of Set 13 | liuhe
# Processing Record 47 of Set 13 | okhotsk
# Processing Record 48 of Set 13 | hermon
# Processing Record 49 of Set 13 | taoudenni
# Processing Record 50 of Set 13 | atar
# Processing Record 1 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 14 | maykain
# City not found. Skipping...
# Processing Record 3 of Set 14 | aksarka
# Processing Record 4 of Set 14 | sao gabriel da cachoeira
# Processing Record 5 of Set 14 | humberto de campos
# Processing Record 6 of Set 14 | hof
# Processing Record 7 of Set 14 | bilibino
# Processing Record 8 of Set 14 | port blair
# Processing Record 9 of Set 14 | bjelovar
# Processing Record 10 of Set 14 | malanje
# Processing Record 11 of Set 14 | port shepstone
# Processing Record 12 of Set 14 | sidi ali
# Processing Record 13 of Set 14 | ilovlya
# Processing Record 14 of Set 14 | dauriya
# Processing Record 15 of Set 14 | kapit
# Processing Record 16 of Set 14 | batagay-alyta
# Processing Record 17 of Set 14 | nampula
# Processing Record 18 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 19 of Set 14 | pangai
# Processing Record 20 of Set 14 | bissau
# Processing Record 21 of Set 14 | ostuni
# Processing Record 22 of Set 14 | naze
# Processing Record 23 of Set 14 | linjiang
# Processing Record 24 of Set 14 | kaeo
# Processing Record 25 of Set 14 | biak
# Processing Record 26 of Set 14 | pirajui
# Processing Record 27 of Set 14 | uaua
# Processing Record 28 of Set 14 | moerai
# Processing Record 29 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 14 | graaff-reinet
# Processing Record 31 of Set 14 | farafangana
# Processing Record 32 of Set 14 | sistranda
# Processing Record 33 of Set 14 | mantua
# Processing Record 34 of Set 14 | neryungri
# Processing Record 35 of Set 14 | santa rosa
# Processing Record 36 of Set 14 | linxia
# Processing Record 37 of Set 14 | balkanabat
# Processing Record 38 of Set 14 | awjilah
# Processing Record 39 of Set 14 | basco
# Processing Record 40 of Set 14 | pemba
# Processing Record 41 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 42 of Set 14 | peleduy
# Processing Record 43 of Set 14 | hovd
# Processing Record 44 of Set 14 | san vicente de canete
# Processing Record 45 of Set 14 | porto novo
# Processing Record 46 of Set 14 | huanan
# Processing Record 47 of Set 14 | lopsmarka
# Processing Record 48 of Set 14 | madang
# Processing Record 49 of Set 14 | gori
# Processing Record 50 of Set 14 | mwingi
# Processing Record 1 of Set 15 | sault sainte marie
# Processing Record 2 of Set 15 | prievidza
# Processing Record 3 of Set 15 | port hedland
# Processing Record 4 of Set 15 | roald
# Processing Record 5 of Set 15 | pakokku
# Processing Record 6 of Set 15 | evensk
# Processing Record 7 of Set 15 | ajdabiya
# Processing Record 8 of Set 15 | keuruu
# Processing Record 9 of Set 15 | ayorou
# Processing Record 10 of Set 15 | san antonio
# Processing Record 11 of Set 15 | san francisco
# Processing Record 12 of Set 15 | rathdrum
# Processing Record 13 of Set 15 | christchurch
# Processing Record 14 of Set 15 | lucapa
# Processing Record 15 of Set 15 | quanzhou
# Processing Record 16 of Set 15 | saint-georges
# Processing Record 17 of Set 15 | uruzgan
# Processing Record 18 of Set 15 | moissala
# Processing Record 19 of Set 15 | launceston
# Processing Record 20 of Set 15 | los barrios
# Processing Record 21 of Set 15 | zhigansk
# Processing Record 22 of Set 15 | san rafael
# Processing Record 23 of Set 15 | chino valley
# Processing Record 24 of Set 15 | vuktyl
# Processing Record 25 of Set 15 | manokwari
# Processing Record 26 of Set 15 | maine-soroa
# Processing Record 27 of Set 15 | gimli
# Processing Record 28 of Set 15 | chiang rai
# Processing Record 29 of Set 15 | challapata
# Processing Record 30 of Set 15 | thetford mines
# Processing Record 31 of Set 15 | mnogovershinnyy
# Processing Record 32 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 33 of Set 15 | qasigiannguit
# Processing Record 34 of Set 15 | palauig
# Processing Record 35 of Set 15 | pringsewu
# Processing Record 36 of Set 15 | bachaquero
# Processing Record 37 of Set 15 | murgab
# Processing Record 38 of Set 15 | ituporanga
# Processing Record 39 of Set 15 | touros
# Processing Record 40 of Set 15 | termiz
# Processing Record 41 of Set 15 | north branch
# Processing Record 42 of Set 15 | seydi
# Processing Record 43 of Set 15 | lukovetskiy
# Processing Record 44 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 45 of Set 15 | mocuba
# Processing Record 46 of Set 15 | sept-iles
# Processing Record 47 of Set 15 | hohhot
# Processing Record 48 of Set 15 | edgewater
# Processing Record 49 of Set 15 | monticello
# Processing Record 50 of Set 15 | puerto lempira
# Processing Record 1 of Set 16 | ayan
# Processing Record 2 of Set 16 | kutum
# Processing Record 3 of Set 16 | lazarev
# Processing Record 4 of Set 16 | sioux lookout
# Processing Record 5 of Set 16 | jinji
# Processing Record 6 of Set 16 | sabha
# Processing Record 7 of Set 16 | nueve de julio
# Processing Record 8 of Set 16 | belgorod
# Processing Record 9 of Set 16 | gravdal
# Processing Record 10 of Set 16 | abu kamal
# Processing Record 11 of Set 16 | sao gabriel
# Processing Record 12 of Set 16 | kautokeino
# Processing Record 13 of Set 16 | leningradskiy
# Processing Record 14 of Set 16 | la ronge
# Processing Record 15 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 16 | yamasaki
# Processing Record 17 of Set 16 | bernay
# Processing Record 18 of Set 16 | novoilinsk
# Processing Record 19 of Set 16 | constitucion
# Processing Record 20 of Set 16 | aonla
# Processing Record 21 of Set 16 | kyra
# Processing Record 22 of Set 16 | avera
# Processing Record 23 of Set 16 | kungurtug
# Processing Record 24 of Set 16 | bayonet point
# Processing Record 25 of Set 16 | dudinka
# Processing Record 26 of Set 16 | poum
# Processing Record 27 of Set 16 | muroto
# Processing Record 28 of Set 16 | amahai
# Processing Record 29 of Set 16 | nipawin
# Processing Record 30 of Set 16 | chumikan
# Processing Record 31 of Set 16 | wlodawa
# Processing Record 32 of Set 16 | la palma
# Processing Record 33 of Set 16 | mao
# Processing Record 34 of Set 16 | natal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ionia  42.9873  -85.0711     91.60        46           0
# 1        Samarai -10.6167  150.6667     82.63        79          75
# 2         Cusuna  15.8500  -85.2333     81.25        73          99
# 3  Krasnoarmeysk  51.0239   45.6969     62.51        82          94
# 4          Pevek  69.7008  170.3133     35.11        78           6
#
#    Wind Speed Country                 Date Current Description
# 0       12.66      US  2022-06-15 23:03:47           clear sky
# 1       10.40      PG  2022-06-15 23:03:47       broken clouds
# 2        8.32      HN  2022-06-15 23:03:47     overcast clouds
# 3        7.99      RU  2022-06-15 23:03:48     overcast clouds
# 4        5.73      RU  2022-06-15 23:03:48           clear sky

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
